# %%
import sys
import warnings

# !pip install category_encoders
# !pip install pandas-profiling
# Out:
# Requirement already satisfied: category_encoders in c:\users\jsm88\anaconda3\lib\site-packages (2.5.0)
# Requirement already satisfied: statsmodels>=0.9.0 in c:\users\jsm88\anaconda3\lib\site-packages (from category_encoders) (0.12.2)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\jsm88\anaconda3\lib\site-packages (from category_encoders) (1.20.3)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\jsm88\anaconda3\lib\site-packages (from category_encoders) (0.24.2)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\jsm88\anaconda3\lib\site-packages (from category_encoders) (0.5.2)
# Requirement already satisfied: pandas>=1.0.5 in c:\users\jsm88\anaconda3\lib\site-packages (from category_encoders) (1.4.1)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\jsm88\anaconda3\lib\site-packages (from category_encoders) (1.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\jsm88\anaconda3\lib\site-packages (from pandas>=1.0.5->category_encoders) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jsm88\anaconda3\lib\site-packages (from pandas>=1.0.5->category_encoders) (2021.3)
# Requirement already satisfied: six in c:\users\jsm88\anaconda3\lib\site-packages (from patsy>=0.5.1->category_encoders) (1.16.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\jsm88\anaconda3\lib\site-packages (from scikit-learn>=0.20.0->category_encoders) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\jsm88\anaconda3\lib\site-packages (from scikit-learn>=0.20.0->category_encoders) (2.2.0)
# Collecting pandas-profiling
#   Downloading pandas_profiling-3.2.0-py2.py3-none-any.whl (262 kB)
# Requirement already satisfied: requests>=2.24.0 in c:\users\jsm88\anaconda3\lib\site-packages (from pandas-profiling) (2.26.0)
# Collecting tangled-up-in-unicode==0.2.0
#   Downloading tangled_up_in_unicode-0.2.0-py3-none-any.whl (4.7 MB)
# Collecting pydantic>=1.8.1
#   Downloading pydantic-1.9.1-cp39-cp39-win_amd64.whl (2.0 MB)
# Collecting missingno>=0.4.2
#   Downloading missingno-0.5.1-py3-none-any.whl (8.7 kB)
# Collecting visions[type_image_path]==0.7.4
#   Downloading visions-0.7.4-py3-none-any.whl (102 kB)
# Requirement already satisfied: jinja2>=2.11.1 in c:\users\jsm88\anaconda3\lib\site-packages (from pandas-profiling) (2.11.3)
# Requirement already satisfied: matplotlib>=3.2.0 in c:\users\jsm88\anaconda3\lib\site-packages (from pandas-profiling) (3.5.1)
# Collecting multimethod>=1.4
#   Downloading multimethod-1.8-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\jsm88\anaconda3\lib\site-packages (from pandas-profiling) (1.20.3)
# Requirement already satisfied: joblib~=1.1.0 in c:\users\jsm88\anaconda3\lib\site-packages (from pandas-profiling) (1.1.0)
# Collecting markupsafe~=2.1.1
#   Downloading MarkupSafe-2.1.1-cp39-cp39-win_amd64.whl (17 kB)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\jsm88\anaconda3\lib\site-packages (from pandas-profiling) (1.7.1)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3 in c:\users\jsm88\anaconda3\lib\site-packages (from pandas-profiling) (1.4.1)
# Requirement already satisfied: PyYAML>=5.0.0 in c:\users\jsm88\anaconda3\lib\site-packages (from pandas-profiling) (6.0)
# Requirement already satisfied: seaborn>=0.10.1 in c:\users\jsm88\anaconda3\lib\site-packages (from pandas-profiling) (0.11.2)
# Collecting htmlmin>=0.1.12
#   Downloading htmlmin-0.1.12.tar.gz (19 kB)
# Collecting phik>=0.11.1
#   Downloading phik-0.12.2-cp39-cp39-win_amd64.whl (685 kB)
# Requirement already satisfied: tqdm>=4.48.2 in c:\users\jsm88\anaconda3\lib\site-packages (from pandas-profiling) (4.62.3)
# Requirement already satisfied: networkx>=2.4 in c:\users\jsm88\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (2.6.3)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\jsm88\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (21.2.0)
# Requirement already satisfied: Pillow in c:\users\jsm88\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (8.4.0)
# Collecting imagehash
#   Downloading ImageHash-4.2.1.tar.gz (812 kB)
# Requirement already satisfied: cycler>=0.10 in c:\users\jsm88\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (0.10.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jsm88\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\jsm88\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (21.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\jsm88\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\jsm88\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\jsm88\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (2.8.2)
# Requirement already satisfied: six in c:\users\jsm88\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib>=3.2.0->pandas-profiling) (1.16.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jsm88\anaconda3\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling) (2021.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\jsm88\anaconda3\lib\site-packages (from pydantic>=1.8.1->pandas-profiling) (3.10.0.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\jsm88\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jsm88\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\jsm88\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jsm88\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling) (2021.10.8)
# Requirement already satisfied: colorama in c:\users\jsm88\anaconda3\lib\site-packages (from tqdm>=4.48.2->pandas-profiling) (0.4.4)
# Requirement already satisfied: PyWavelets in c:\users\jsm88\anaconda3\lib\site-packages (from imagehash->visions[type_image_path]==0.7.4->pandas-profiling) (1.1.1)
# Building wheels for collected packages: htmlmin, imagehash
#   Building wheel for htmlmin (setup.py): started
#   Building wheel for htmlmin (setup.py): finished with status 'done'
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27098 sha256=8ca0d7577dac88583d1c2ec5a3a13ad14662390248eb59317487fdd43fbe801a
#   Stored in directory: c:\users\jsm88\appdata\local\pip\cache\wheels\1d\05\04\c6d7d3b66539d9e659ac6dfe81e2d0fd4c1a8316cc5a403300
#   Building wheel for imagehash (setup.py): started
#   Building wheel for imagehash (setup.py): finished with status 'done'
#   Created wheel for imagehash: filename=ImageHash-4.2.1-py2.py3-none-any.whl size=295207 sha256=8671e004d7882b4854ad3756085df473e5989bbe298f1d5ce9c1bdd910516806
#   Stored in directory: c:\users\jsm88\appdata\local\pip\cache\wheels\51\f9\a5\740af2fdb0ad1edf79aabdc41531be0b6f0b2e2be684c388cf
# Successfully built htmlmin imagehash
# Installing collected packages: tangled-up-in-unicode, multimethod, visions, markupsafe, imagehash, pydantic, phik, missingno, htmlmin, pandas-profiling
#   Attempting uninstall: markupsafe
#     Found existing installation: MarkupSafe 1.1.1
#     Uninstalling MarkupSafe-1.1.1:
#       Successfully uninstalled MarkupSafe-1.1.1
# Successfully installed htmlmin-0.1.12 imagehash-4.2.1 markupsafe-2.1.1 missingno-0.5.1 multimethod-1.8 pandas-profiling-3.2.0 phik-0.12.2 pydantic-1.9.1 tangled-up-in-unicode-0.2.0 visions-0.7.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# anaconda-project 0.10.1 requires ruamel-yaml, which is not installed.
# cookiecutter 1.7.2 requires MarkupSafe<2.0.0, but you have markupsafe 2.1.1 which is incompatible.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
target = 'vacc_h1n1_f'
# target = 'vacc_seas_f'
train = pd.merge(pd.read_csv('https://ds-lecture-data.s3.ap-northeast-2.amazonaws.com/vacc_flu/train.csv'), 
                 pd.read_csv('https://ds-lecture-data.s3.ap-northeast-2.amazonaws.com/vacc_flu/train_labels.csv')[target], left_index=True, right_index=True)
test = pd.read_csv('https://ds-lecture-data.s3.ap-northeast-2.amazonaws.com/vacc_flu/test.csv')
sample_submission = pd.read_csv('https://ds-lecture-data.s3.ap-northeast-2.amazonaws.com/vacc_flu/submission.csv')

# %%
train.head().T
# Out:
#                                                    0  \
# h1n1_concern                                     NaN
# h1n1_knowledge                                   NaN
# behavioral_antiviral_meds                        NaN
# behavioral_avoidance                             NaN
# behavioral_face_mask                             NaN
# behavioral_wash_hands                            NaN
# behavioral_large_gatherings                      NaN
# behavioral_outside_home                          NaN
# behavioral_touch_face                            NaN
# doctor_recc_h1n1                                 0.0
# doctor_recc_seasonal                             0.0
# chronic_med_condition                            0.0
# child_under_6_months                             NaN
# health_insurance                                 1.0
# health_worker                                    NaN
# opinion_h1n1_vacc_effective                      NaN
# opinion_h1n1_risk                                NaN
# opinion_h1n1_sick_from_vacc                      NaN
# opinion_seas_vacc_effective                      NaN
# opinion_seas_risk                                NaN
# opinion_seas_sick_from_vacc                      NaN
# agegrp                                 10 - 17 Years
# education_comp                                   NaN
# raceeth4_i                                         3
# sex_i                                              1
# inc_pov                                            2
# marital                                          NaN
# rent_own_r                                       2.0
# employment_status                                NaN
# census_region                                      4
# census_msa                   MSA, Not Principle City
# n_adult_r                                        2.0
# household_children                               3.0
# n_people_r                                       5.0
# employment_industry                              NaN
# employment_occupation                            NaN
# hhs_region                                         9
# state                                     CALIFORNIA
# vacc_h1n1_f                                        0
#
#                                                                             1  \
# h1n1_concern                                                              3.0
# h1n1_knowledge                                                            1.0
# behavioral_antiviral_meds                                                 0.0
# behavioral_avoidance                                                      0.0
# behavioral_face_mask                                                      0.0
# behavioral_wash_hands                                                     1.0
# behavioral_large_gatherings                                               0.0
# behavioral_outside_home                                                   0.0
# behavioral_touch_face                                                     1.0
# doctor_recc_h1n1                                                          0.0
# doctor_recc_seasonal                                                      0.0
# chronic_med_condition                                                     0.0
# child_under_6_months                                                      0.0
# health_insurance                                                          NaN
# health_worker                                                             0.0
# opinion_h1n1_vacc_effective                                    Very Effective
# opinion_h1n1_risk                                                    Very Low
# opinion_h1n1_sick_from_vacc                                  Not Very Worried
# opinion_seas_vacc_effective                                    Very Effective
# opinion_seas_risk                                                Somewhat Low
# opinion_seas_sick_from_vacc                                Not At All Worried
# agegrp                                                          45 - 54 Years
# education_comp                                                            3.0
# raceeth4_i                                                                  3
# sex_i                                                                       1
# inc_pov                                                                     2
# marital                                                                   2.0
# rent_own_r                                                                1.0
# employment_status                                                    Employed
# census_region                                                               2
# census_msa                                                MSA, Principle City
# n_adult_r                                                                 1.0
# household_children                                                        0.0
# n_people_r                                                                1.0
# employment_industry                Accommodation and Food Services Industries
# employment_occupation        Food Preparation and Serving Related Occupations
# hhs_region                                                                  7
# state                                                                NEBRASKA
# vacc_h1n1_f                                                                 0
#
#                                                                           2  \
# h1n1_concern                                                            2.0
# h1n1_knowledge                                                          1.0
# behavioral_antiviral_meds                                               0.0
# behavioral_avoidance                                                    1.0
# behavioral_face_mask                                                    0.0
# behavioral_wash_hands                                                   1.0
# behavioral_large_gatherings                                             1.0
# behavioral_outside_home                                                 0.0
# behavioral_touch_face                                                   1.0
# doctor_recc_h1n1                                                        0.0
# doctor_recc_seasonal                                                    1.0
# chronic_med_condition                                                   0.0
# child_under_6_months                                                    0.0
# health_insurance                                                        NaN
# health_worker                                                           0.0
# opinion_h1n1_vacc_effective                              Somewhat Effective
# opinion_h1n1_risk                                              Somewhat Low
# opinion_h1n1_sick_from_vacc                                    Very Worried
# opinion_seas_vacc_effective                              Somewhat Effective
# opinion_seas_risk                                              Somewhat Low
# opinion_seas_sick_from_vacc                                    Very Worried
# agegrp                                                        45 - 54 Years
# education_comp                                                          3.0
# raceeth4_i                                                                3
# sex_i                                                                     1
# inc_pov                                                                   2
# marital                                                                 2.0
# rent_own_r                                                              2.0
# employment_status                                                  Employed
# census_region                                                             1
# census_msa                                          MSA, Not Principle City
# n_adult_r                                                               1.0
# household_children                                                      2.0
# n_people_r                                                              3.0
# employment_industry               Transportation and Warehousing Industries
# employment_occupation        Transportation and Material Moving Occupations
# hhs_region                                                                1
# state                                                         MASSACHUSETTS
# vacc_h1n1_f                                                               0
#
#                                                                              3  \
# h1n1_concern                                                               2.0
# h1n1_knowledge                                                             2.0
# behavioral_antiviral_meds                                                  1.0
# behavioral_avoidance                                                       1.0
# behavioral_face_mask                                                       0.0
# behavioral_wash_hands                                                      1.0
# behavioral_large_gatherings                                                0.0
# behavioral_outside_home                                                    0.0
# behavioral_touch_face                                                      0.0
# doctor_recc_h1n1                                                           0.0
# doctor_recc_seasonal                                                       1.0
# chronic_med_condition                                                      1.0
# child_under_6_months                                                       0.0
# health_insurance                                                           1.0
# health_worker                                                              0.0
# opinion_h1n1_vacc_effective                                     Very Effective
# opinion_h1n1_risk                                                     Very Low
# opinion_h1n1_sick_from_vacc                                   Not Very Worried
# opinion_seas_vacc_effective                                     Very Effective
# opinion_seas_risk                                                    Very High
# opinion_seas_sick_from_vacc                                 Not At All Worried
# agegrp                                                           35 - 44 Years
# education_comp                                                             4.0
# raceeth4_i                                                                   1
# sex_i                                                                        2
# inc_pov                                                                      1
# marital                                                                    1.0
# rent_own_r                                                                 1.0
# employment_status                                                     Employed
# census_region                                                                3
# census_msa                                             MSA, Not Principle City
# n_adult_r                                                                  2.0
# household_children                                                         2.0
# n_people_r                                                                 4.0
# employment_industry          Professional, Scientific, and Technical Servic...
# employment_occupation                                        Legal Occupations
# hhs_region                                                                   6
# state                                                                LOUISIANA
# vacc_h1n1_f                                                                  0
#
#                                                                          4
# h1n1_concern                                                           1.0
# h1n1_knowledge                                                         2.0
# behavioral_antiviral_meds                                              0.0
# behavioral_avoidance                                                   1.0
# behavioral_face_mask                                                   0.0
# behavioral_wash_hands                                                  1.0
# behavioral_large_gatherings                                            0.0
# behavioral_outside_home                                                0.0
# behavioral_touch_face                                                  1.0
# doctor_recc_h1n1                                                       0.0
# doctor_recc_seasonal                                                   0.0
# chronic_med_condition                                                  0.0
# child_under_6_months                                                   0.0
# health_insurance                                                       1.0
# health_worker                                                          0.0
# opinion_h1n1_vacc_effective                                 Very Effective
# opinion_h1n1_risk                                                 Very Low
# opinion_h1n1_sick_from_vacc                             Not At All Worried
# opinion_seas_vacc_effective                           Not At All Effective
# opinion_seas_risk                                                 Very Low
# opinion_seas_sick_from_vacc                             Not At All Worried
# agegrp                                                       55 - 64 Years
# education_comp                                                         3.0
# raceeth4_i                                                               3
# sex_i                                                                    2
# inc_pov                                                                  2
# marital                                                                1.0
# rent_own_r                                                             1.0
# employment_status                                                 Employed
# census_region                                                            3
# census_msa                                         MSA, Not Principle City
# n_adult_r                                                              3.0
# household_children                                                     0.0
# n_people_r                                                             3.0
# employment_industry                          Education Services Industries
# employment_occupation        Office and Administrative Support Occupations
# hhs_region                                                               4
# state                                                              ALABAMA
# vacc_h1n1_f                                                              1
